# %%
import pandas as pd
from sklearn.feature_extraction import DictVectorizer
import json
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.pipeline import make_pipeline
import numpy as np
import xgboost as xgb
import pickle
import os

# %%
pd.set_option('display.max_columns', None)

TRAIN_DATA_PATH = '../data/train_2022_2023.csv.gz'
VAL_DATA_PATH = '../data/val_2024.csv.gz'

# %%
temp_df = pd.read_csv(TRAIN_DATA_PATH, compression='gzip', nrows=0)
all_cols = temp_df.columns.tolist()

remove_cols = ['id', 'updated_on', 'block', 'iucr', 'beat', 'description', 'latitude', 'longitude', 'location', 'year', 'y_coordinate', 'x_coordinate', 'case_number', 'id']
include_cols = [inc_col for inc_col in all_cols if inc_col not in remove_cols]

# %%
df = pd.read_csv(TRAIN_DATA_PATH, compression='gzip', usecols=include_cols, parse_dates=['date'])
df.head()
# Out:
#         date                primary_type location_description  arrest  \
# 0 2022-01-01                 SEX OFFENSE        ATHLETIC CLUB   False
# 1 2022-01-01          DECEPTIVE PRACTICE            RESIDENCE   False
# 2 2022-01-01                     BATTERY            APARTMENT   False
# 3 2022-01-01     CRIMINAL SEXUAL ASSAULT            RESIDENCE   False
# 4 2022-01-01  OFFENSE INVOLVING CHILDREN            RESIDENCE   False
#
#    domestic  district  ward  community_area fbi_code
# 0     False        22  19.0            75.0       17
# 1     False        11  37.0            23.0       11
# 2      True        16  45.0            11.0      08B
# 3     False        19  44.0             6.0       02
# 4      True         8  14.0            63.0       17

# %%
for col in df.columns.tolist():
    print(f'{col}: {df[col].nunique()}')
# Out:
# date: 236566
# primary_type: 31
# location_description: 143
# arrest: 2
# domestic: 2
# district: 23
# ward: 50
# community_area: 77
# fbi_code: 26

# %%
# Extract temporal features
df['hour'] = df['date'].dt.hour  # 0-23
df['day_of_week'] = df['date'].dt.weekday  # 0=Monday to 6=Sunday
df['month'] = df['date'].dt.month  # 1-12
df['quarter'] = df['date'].dt.quarter  # 1-4

# Binary flags
df['is_night'] = ((df['hour'] >= 18) | (df['hour'] < 6)).astype(int)  # 1 if True, 0 else
df['is_weekend'] = (df['day_of_week'] >= 5).astype(int)

# %%
# countries and their regions
with open ('./location_description.json', 'r') as file:
    map_loc_desc = json.load(file)
    
df['location_group'] = df['location_description'].map(map_loc_desc).fillna("Unknown/Other")
df.drop(columns=['date', 'location_description'], inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 503052 entries, 0 to 503051
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   primary_type    503052 non-null  object
#  1   arrest          503052 non-null  bool
#  2   domestic        503052 non-null  bool
#  3   district        503052 non-null  int64
#  4   ward            503039 non-null  float64
#  5   community_area  503013 non-null  float64
#  6   fbi_code        503052 non-null  object
#  7   hour            503052 non-null  int32
#  8   day_of_week     503052 non-null  int32
#  9   month           503052 non-null  int32
#  10  quarter         503052 non-null  int32
#  11  is_night        503052 non-null  int64
#  12  is_weekend      503052 non-null  int64
#  13  location_group  503052 non-null  object
# dtypes: bool(2), float64(2), int32(4), int64(3), object(3)
# memory usage: 39.3+ MB

# %%
df = df.dropna()

# %%
feature_cols = [
    'primary_type', 'domestic', 'district', 'ward', 'community_area', 'fbi_code',
    'hour', 'day_of_week', 'month', 'quarter', 'is_night', 'is_weekend', 'location_group'
]

# %%
for col in df.columns.tolist():
    print(f'{col}: {df[col].nunique()}')
# Out:
# primary_type: 31
# arrest: 2
# domestic: 2
# district: 23
# ward: 50
# community_area: 77
# fbi_code: 26
# hour: 24
# day_of_week: 7
# month: 12
# quarter: 4
# is_night: 2
# is_weekend: 2
# location_group: 15

# %%
for c in df.columns.tolist():
    print(df[c].value_counts())
    print()
# Out:
# primary_type
# THEFT                                112383
# BATTERY                               85200
# CRIMINAL DAMAGE                       57337
# MOTOR VEHICLE THEFT                   50722
# ASSAULT                               43440
# DECEPTIVE PRACTICE                    34495
# OTHER OFFENSE                         30338
# ROBBERY                               20016
# WEAPONS VIOLATION                     17388
# BURGLARY                              15081
# NARCOTICS                             10210
# CRIMINAL TRESPASS                      8941
# OFFENSE INVOLVING CHILDREN             3630
# CRIMINAL SEXUAL ASSAULT                3279
# SEX OFFENSE                            2594
# PUBLIC PEACE VIOLATION                 1574
# HOMICIDE                               1375
# STALKING                                982
# INTERFERENCE WITH PUBLIC OFFICER        978
# ARSON                                   933
# PROSTITUTION                            492
# INTIMIDATION                            420
# LIQUOR LAW VIOLATION                    389
# CONCEALED CARRY LICENSE VIOLATION       381
# KIDNAPPING                              257
# OBSCENITY                                90
# GAMBLING                                 24
# HUMAN TRAFFICKING                        23
# PUBLIC INDECENCY                         11
# OTHER NARCOTIC VIOLATION                  9
# NON-CRIMINAL                              8
# Name: count, dtype: int64
#
# arrest
# False    442673
# True      60327
# Name: count, dtype: int64
#
# domestic
# False    410989
# True      92011
# Name: count, dtype: int64
#
# district
# 8     31888
# 6     30575
# 12    30366
# 4     29010
# 11    27957
# 1     27464
# 19    26062
# 25    26040
# 18    25803
# 2     25400
# 3     25188
# 9     22079
# 7     21224
# 10    21096
# 5     20342
# 16    19036
# 24    17857
# 14    17544
# 15    16605
# 22    15977
# 17    14880
# 20    10579
# 31       28
# Name: count, dtype: int64
#
# ward
# 27.0    23219
# 42.0    22402
# 28.0    21576
# 6.0     18563
# 24.0    17145
# 4.0     16294
# 20.0    15797
# 8.0     15643
# 7.0     15547
# 21.0    15188
# 17.0    14933
# 9.0     14912
# 3.0     14779
# 16.0    13489
# 37.0    13062
# 34.0    12658
# 5.0     12508
# 29.0    10935
# 25.0    10163
# 10.0     9411
# 1.0      9281
# 49.0     8737
# 26.0     8375
# 46.0     8314
# 44.0     8152
# 2.0      7787
# 15.0     7446
# 18.0     7323
# 14.0     6881
# 36.0     6793
# 32.0     6614
# 48.0     6505
# 11.0     6441
# 41.0     6439
# 31.0     6426
# 22.0     6423
# 40.0     6337
# 50.0     6014
# 12.0     5960
# 35.0     5927
# 30.0     5698
# 45.0     5644
# 43.0     5602
# 47.0     5458
# 23.0     5401
# 33.0     5339
# 13.0     5186
# 39.0     5119
# 38.0     4625
# 19.0     4529
# Name: count, dtype: int64
#
# community_area
# 25.0    24976
# 8.0     21826
# 28.0    19940
# 43.0    17119
# 32.0    16866
#         ...
# 37.0     1372
# 12.0     1156
# 74.0     1086
# 47.0      692
# 9.0       597
# Name: count, Length: 77, dtype: int64
#
# fbi_code
# 06     112384
# 08B     70612
# 14      57337
# 07      50722
# 08A     36588
# 26      32996
# 11      29875
# 03      20016
# 15      17777
# 04B     15576
# 05      15080
# 04A     14992
# 18      10210
# 10       4393
# 02       3723
# 17       3497
# 24       2524
# 01A      1362
# 20       1257
# 09        933
# 16        492
# 22        389
# 13        139
# 12         88
# 19         25
# 01B        13
# Name: count, dtype: int64
#
# hour
# 0     40122
# 12    28758
# 15    26953
# 17    26833
# 18    26408
# 16    26216
# 19    25686
# 20    24878
# 14    23384
# 21    23164
# 13    22271
# 22    22257
# 11    21836
# 10    21301
# 9     21148
# 23    20217
# 8     17078
# 1     16522
# 2     14600
# 7     12646
# 3     12355
# 4     10095
# 6      9413
# 5      8859
# Name: count, dtype: int64
#
# day_of_week
# 4    73963
# 5    73572
# 6    71753
# 2    71176
# 1    71105
# 0    70753
# 3    70678
# Name: count, dtype: int64
#
# month
# 8     46600
# 7     46399
# 10    46364
# 9     45057
# 6     43600
# 5     42492
# 11    42289
# 12    41317
# 3     39225
# 4     38861
# 1     37038
# 2     33758
# Name: count, dtype: int64
#
# quarter
# 3    138056
# 4    129970
# 2    124953
# 1    110021
# Name: count, dtype: int64
#
# is_night
# 0    257837
# 1    245163
# Name: count, dtype: int64
#
# is_weekend
# 0    357675
# 1    145325
# Name: count, dtype: int64
#
# location_group
# Street/Public Open               206364
# Residential                      178200
# Commercial Retail                 48935
# Food/Entertainment/Recreation     17683
# Unknown/Other                     10289
# Educational                        8600
# Public Transit                     8333
# Vehicle/Transport Private          8174
# Healthcare                         5183
# Government/Institutional           4137
# Airport/Aviation                   2824
# Financial/Services                 1922
# Industrial/Construction            1129
# Religious/Cultural                  922
# Abandoned/Utility                   305
# Name: count, dtype: int64

# %%
df.isna().sum()
# Out:
# primary_type      0
# arrest            0
# domestic          0
# district          0
# ward              0
# community_area    0
# fbi_code          0
# hour              0
# day_of_week       0
# month             0
# quarter           0
# is_night          0
# is_weekend        0
# location_group    0
# dtype: int64

# %%
X_train = df[feature_cols]
y_train = df['arrest'].astype('int')

# %%
# # Class weights for imbalance (fit on train)
# classes = np.unique(y_train)
# class_weights = compute_class_weight('balanced', classes=classes, y=y_train)
# sample_weights = {cls: w for cls, w in zip(classes, class_weights)}

# %%
# class_weights

# %%
# sample_weights

# %%
X_train_dict = X_train.to_dict(orient='records')

# %%
model = xgb.XGBClassifier(
    objective='binary:logistic',
    eval_metric='auc',
    random_state=42,
    n_estimators=100,
    learning_rate=0.1,
    max_depth=6,
    subsample=0.8,
    colsample_bytree=0.8,
    # scale_pos_weight=sample_weights[1]
)

# %%
pipeline = make_pipeline(
    DictVectorizer(sparse=True, dtype=np.float32),
    model
)

pipeline.fit(X_train_dict, y_train)
# Out:
# Pipeline(steps=[('dictvectorizer',
#                  DictVectorizer(dtype=<class 'numpy.float32'>)),
#                 ('xgbclassifier',
#                  XGBClassifier(base_score=None, booster=None, callbacks=None,
#                                colsample_bylevel=None, colsample_bynode=None,
#                                colsample_bytree=0.8, device=None,
#                                early_stopping_rounds=None,
#                                enable_categorical=False, eval_metric='auc',
#                                feature_types=None, feature_weights=None,
#                                gamma=None, grow_policy=None,
#                                importance_type=None,
#                                interaction_constraints=None, learning_rate=0.1,
#                                max_bin=None, max_cat_threshold=None,
#                                max_cat_to_onehot=None, max_delta_step=None,
#                                max_depth=6, max_leaves=None,
#                                min_child_weight=None, missing=nan,
#                                monotone_constraints=None, multi_strategy=None,
#                                n_estimators=100, n_jobs=None,
#                                num_parallel_tree=None, ...))])

# %%
# Evaluate on val
y_val_pred_proba = pipeline.predict_proba(X_train_dict)[:, 1]
y_val_pred = pipeline.predict(X_train_dict)

# %%
auc_val = roc_auc_score(y_train, y_val_pred_proba)
print(f"Validation AUC-ROC: {auc_val:.4f}")
print("\nClassification Report (Val):\n", classification_report(y_train, y_val_pred))
# Out:
# Validation AUC-ROC: 0.8724
#
# Classification Report (Val):
#                precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95    442673
#            1       0.83      0.39      0.54     60327
#
#     accuracy                           0.92    503000
#    macro avg       0.88      0.69      0.75    503000
# weighted avg       0.91      0.92      0.90    503000

# %%
# Ensure model directory exists
os.makedirs('../models', exist_ok=True)

with open('../models/xgb_model.pkl', 'wb') as f_out:
    pickle.dump(pipeline, f_out)

# %%
with open('../models/xgb_model.pkl', 'rb') as f_in:
    pipeline = pickle.load(f_in)
